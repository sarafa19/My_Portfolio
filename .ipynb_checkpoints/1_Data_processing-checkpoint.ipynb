# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
df1=pd.read_csv("accidentsVelo.csv")
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_9872\2382202979.py:1: DtypeWarning: Columns (8,9,20,21,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv("accidentsVelo.csv")

# %%
df1
# Out:
#             Num_Acc        date    an     mois      jour   hrmn dep    com  \
# 0      200500000030  2005-01-13  2005  janvier     jeudi  19:45  62  62331
# 1      200500000034  2005-01-19  2005  janvier  mercredi  10:45  62  62022
# 2      200500000078  2005-01-26  2005  janvier  mercredi  13:15  02  02173
# 3      200500000093  2005-01-03  2005  janvier     lundi  13:30  02  02810
# 4      200500000170  2005-01-29  2005  janvier    samedi  18:30  76  76196
# ...             ...         ...   ...      ...       ...    ...  ..    ...
# 74753  202100056317  2021-01-02  2021  janvier    samedi  18:30  44  44168
# 74754  202100056362  2021-01-04  2021  janvier     lundi  08:20  64  64138
# 74755  202100056404  2021-01-01  2021  janvier  vendredi  16:55  54  54395
# 74756  202100056424  2021-01-02  2021  janvier    samedi  15:40  75  75110
# 74757  202100056508  2021-01-01  2021  janvier  vendredi  12:20  64  64400
#
#                  lat            long  ...  secuexist  equipement  obs  obsm  \
# 0               50.3            2.84  ...          3           0  0.0   2.0
# 1                0.0             0.0  ...          3           0  0.0   2.0
# 2                0.0             0.0  ...          2           2  0.0   2.0
# 3             49.255           3.094  ...          3           0  0.0   2.0
# 4                0.0             0.0  ...          1           9  0.0   2.0
# ...              ...             ...  ...        ...         ...  ...   ...
# 74753  47,3777890000   -2,1976410000  ...          2         NaN  0.0   0.0
# 74754  43,2309460000   -0,2765840000  ...          1           2  0.0   2.0
# 74755  48,6849869839    6,1760189384  ...          1           2  0.0   2.0
# 74756  48,8769050000    2,3665940000  ...          2         NaN  0.0   2.0
# 74757  43,1465730000   -0,1955440000  ...          1         2/6  0.0   0.0
#
#        choc  manv       vehiculeid  typevehicules  manoeuvehicules  \
# 0       8.0  11.0  200500000030B02             18               17
# 1       1.0   1.0  200500000034B02             10               15
# 2       1.0   1.0  200500000078B02              7               15
# 3       3.0  21.0  200500000093B02              7               21
# 4       4.0   2.0  200500000170A01             10                2
# ...     ...   ...              ...            ...              ...
# 74753   8.0   1.0  202100056317B01              7               14
# 74754   0.0   1.0  202100056362B01              7               15
# 74755   1.0  25.0  202100056404A01              7                1
# 74756   1.0   1.0  202100056424A01              7                9
# 74757   8.0   1.0  202100056508A01            NaN              NaN
#
#        numVehicules
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 74753           1.0
# 74754           1.0
# 74755           1.0
# 74756           1.0
# 74757           NaN
#
# [74758 rows x 39 columns]

# %%
df1=df1.drop(columns=['int','col','catr','circ','nbv','plan','lartpc','larrout','surf','infra','situ','obsm','manv','vehiculeid','manoeuvehicules'])
col_names=['Numero_accident','date','an','mois','jour','heure','departement','commune','latitude','longitude','agglomération','luminosite','atmos','profil_route','gravite','sexe','age','trajet','securite_existant','equipement','obs','choc','typevehicules','nombreVehicules']     
df1.columns=col_names

# %%
df1['date']=pd.to_datetime(df1['date'])

# %%
df1['mois']=df1['mois'].astype('category')
df1['jour']=df1['jour'].astype('category')
df1['departement']=df1['departement'].astype('category')
df1['commune']=df1['commune'].astype('category')
df1['equipement']=df1['equipement'].astype('category')
df1['typevehicules']=df1['typevehicules'].astype('category')

# %%
df1['latitude'] = df1['latitude'].astype(str)
df1['latitude'] = df1['latitude'].str.replace(',','.')
df1['latitude'] = pd.to_numeric(df1['latitude'], errors='coerce')

# %%
df1['longitude'] = df1['longitude'].astype(str)
df1['longitude'] = df1['longitude'].str.replace(',','.')
df1['longitude'] = pd.to_numeric(df1['longitude'], errors='coerce')

# %%
import numpy as np

def is_valid_time(time_str):
    try:
        pd.to_datetime(time_str, format='%H:%M')
        return True
    except ValueError:
        return False
    
df1['heure'] = df1['heure'].apply(lambda x: x if is_valid_time(x) else np.nan)
df1['heure'] = pd.to_datetime(df1['heure'], format='%H:%M', errors='coerce')

# %% [markdown]
# ### Vérifier les valeurs manquantes

# %%
msno.matrix(df1)
# Out:
# <Axes: >

# %%
df1=df1.dropna()
missing_percentage = df1.isnull().mean() * 100
missing_percentage

# %%
unique_counts = df1.nunique()
unique_counts
# Out:
# Numero_accident      71205
# date                  6171
# an                      17
# mois                    12
# jour                     7
# heure                 1049
# departement            113
# commune              10797
# latitude             26887
# longitude            28411
# agglomération            2
# luminosite               5
# atmos                    9
# profil_route             5
# gravite                  4
# sexe                     3
# age                    111
# trajet                   8
# securite_existant        4
# equipement              38
# obs                     19
# choc                    11
# typevehicules          128
# nombreVehicules          5
# dtype: int64

# %%
dictionnaires_valeurs={
    'agglomération':{
        0:'Hors agglomération',
        1:'En agglomération'
    },
    'luminosite': {
        1: "Plein jour",
        2: "Crépuscule ou aube",
        3: "Nuit sans éclairage public",
        4: "Nuit avec éclairage public non allumé",
        5: "Nuit avec éclairage public allumé"
    },
    'atmos': {
        1: "Normale",
        2: "Pluie légère",
        3: "Pluie forte",
        4: "Neige - grêle",
        5: "Brouillard - fumée",
        6: "Vent fort - tempête",
        7: "Temps éblouissant",
        8: "Temps couvert",
        9: "Autre"
    },
    'profil_route': {
        1: "Plat",
        2: "Pente",
        3: "Sommet de côte",
        4: "Bas de côte",
        5: "Virage"
    },
    'gravite': {
        1: "Indemne",
        2: "Blessé léger",
        3: "Blessé hospitalisé",
        4: "Tué"
    }, 
        'sexe': {
        1: "Homme",
        2: "Femme",
        0: "Inconnu"
    },
    'trajet': {
        1: "Domicile - Travail",
        2: "Domicile - Ecole",
        3: "Courses - Achats",
        4: "Utilisation professionnelle",
        5: "Promenade - Loisirs",
        6: "Autre",
        7: "Non renseigné",
        8: "Sans objet"
    },
    'securite_existant': {
        1: "Ceinture de sécurité",
        2: "Casque",
        3: "Non utilisé",
        4: "Inconnu"
    },
    'choc': {
        1: "Avant",
        2: "Arrière",
        3: "Côté",
        4: "Multiple",
        5: "Autre"
     },
         'typevehicules': {
        1: "Bicyclette",
        2: "Vélo électrique",
        7: "Voiture",
        10: "Poids lourd",
        11: "Motocyclette",
        'Autre':"Tous les autres types de véhicules non spécifiés" ,
    }        
}

# %%
df1['typevehicules'] = df1['typevehicules'].apply(lambda x: x if x in dictionnaires_valeurs['typevehicules'] else 'Autre')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74758 entries, 0 to 74757
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Numero_accident    74758 non-null  int64
#  1   date               74758 non-null  datetime64[ns]
#  2   an                 74758 non-null  int64
#  3   mois               74758 non-null  category
#  4   jour               74758 non-null  category
#  5   heure              61124 non-null  object
#  6   departement        74758 non-null  category
#  7   commune            74758 non-null  category
#  8   latitude           74758 non-null  float64
#  9   longitude          74490 non-null  float64
#  10  agglomération      74758 non-null  int64
#  11  luminosite         74758 non-null  int64
#  12  atmos              74755 non-null  float64
#  13  profil_route       74581 non-null  float64
#  14  gravite            74758 non-null  int64
#  15  sexe               74758 non-null  int64
#  16  age                74732 non-null  float64
#  17  trajet             74755 non-null  float64
#  18  securite_existant  74758 non-null  int64
#  19  equipement         71017 non-null  category
#  20  obs                74732 non-null  float64
#  21  choc               74746 non-null  float64
#  22  typevehicules      64465 non-null  category
#  23  nombreVehicules    64465 non-null  float64
# dtypes: category(6), datetime64[ns](1), float64(9), int64(7), object(1)
# memory usage: 11.2+ MB

# %%
df1.to_pickle('AccidentsVelo2.pkl')
